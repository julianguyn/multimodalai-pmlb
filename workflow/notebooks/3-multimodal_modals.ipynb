# %%
import os
import sys
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

dir = "/Users/julianguyen/Documents/multimodal-pmlb"
os.chdir(dir)
sys.path.insert(0, dir)
from workflow.notebooks.utils.helpers import *

np.random.seed(101)

# %%
# load in train files
atc_train = pd.read_csv("data/procdata/model_inputs/atc_train.csv", index_col=0)
rna_train = pd.read_csv("data/procdata/model_inputs/rna_train.csv", index_col=0)
cnv_train = pd.read_csv("data/procdata/model_inputs/cnv_train.csv", index_col=0)
mut_train = pd.read_csv("data/procdata/model_inputs/mut_train.csv", index_col=0)
pheno_train = pd.read_csv("data/procdata/model_inputs/meta_train.csv", index_col=0)

# load in test files
atc_test = pd.read_csv("data/procdata/model_inputs/atc_test.csv", index_col=0)
rna_test = pd.read_csv("data/procdata/model_inputs/rna_test.csv", index_col=0)
cnv_test = pd.read_csv("data/procdata/model_inputs/cnv_test.csv", index_col=0)
mut_test = pd.read_csv("data/procdata/model_inputs/mut_test.csv", index_col=0)
pheno_test = pd.read_csv("data/procdata/model_inputs/meta_test.csv", index_col=0)

# get targest
y_train = pheno_train["doubling_rate"]
y_test = pheno_test["doubling_rate"]

# %% [markdown]
# ## Multimodal Models WITHOUT Cancer Type

# %% [markdown]
# ### Combo 1: All Modalities

# %%
train_df = pd.concat([atc_train, rna_train, cnv_train, mut_train], axis=1)
test_df = pd.concat([atc_test, rna_test, cnv_test, mut_test], axis=1)

# %%
# elastic net
run_elastic_net(train_df, y_train, test_df, y_test, "2-Multimodal-OmicOnly/all_modalities_")

# %% [markdown]
# ### Combo 2: ATAC + RNA + CNV

# %%
train_df = pd.concat([atc_train, rna_train, cnv_train], axis=1)
test_df = pd.concat([atc_test, rna_test, cnv_test], axis=1)

# %%
# elastic net
run_elastic_net(train_df, y_train, test_df, y_test, "2-Multimodal-OmicOnly/atac_rna_cnv_")

# %% [markdown]
# ### Combo 3: ATAC + RNA + MUT

# %%
train_df = pd.concat([atc_train, rna_train, mut_train], axis=1)
test_df = pd.concat([atc_test, rna_test, mut_test], axis=1)

# %%
# elastic net
run_elastic_net(train_df, y_train, test_df, y_test, "2-Multimodal-OmicOnly/atac_rna_mut_")

# %% [markdown]
# ### Combo 4: ATAC + CNV + MUT

# %%
train_df = pd.concat([atc_train, cnv_train, mut_train], axis=1)
test_df = pd.concat([atc_test, cnv_test, mut_test], axis=1)

# %%
# elastic net
run_elastic_net(train_df, y_train, test_df, y_test, "2-Multimodal-OmicOnly/atac_cnv_mut_")

# %% [markdown]
# ### Combo 5: ATAC + RNA

# %%
train_df = pd.concat([atc_train, rna_train], axis=1)
test_df = pd.concat([atc_test, rna_test], axis=1)

# %%
# elastic net
run_elastic_net(train_df, y_train, test_df, y_test, "2-Multimodal-OmicOnly/atac_rna_")

# %% [markdown]
# ### Combo 6: ATAC + CNV

# %%
train_df = pd.concat([atc_train, cnv_train], axis=1)
test_df = pd.concat([atc_test, cnv_test], axis=1)

# %%
# elastic net
run_elastic_net(train_df, y_train, test_df, y_test, "2-Multimodal-OmicOnly/atac_cnv_")

# %% [markdown]
# ### Combo 7: ATAC + MUT

# %%
train_df = pd.concat([atc_train, mut_train], axis=1)
test_df = pd.concat([atc_test, mut_test], axis=1)

# %%
# elastic net
run_elastic_net(train_df, y_train, test_df, y_test, "2-Multimodal-OmicOnly/atac_mut_")

# %% [markdown]
# ### Combo 8: RNA + CNV + MUT

# %%
train_df = pd.concat([rna_train, cnv_train, mut_train], axis=1)
test_df = pd.concat([rna_test, cnv_test, mut_test], axis=1)

# %%
# elastic net
run_elastic_net(train_df, y_train, test_df, y_test, "2-Multimodal-OmicOnly/rna_cnv_mut_")

# %% [markdown]
# ### Combo 9: RNA + CNV

# %%
train_df = pd.concat([rna_train, cnv_train], axis=1)
test_df = pd.concat([rna_test, cnv_test], axis=1)

# %%
# elastic net
run_elastic_net(train_df, y_train, test_df, y_test, "2-Multimodal-OmicOnly/rna_cnv_")

# %% [markdown]
# ### Combo 10: RNA + MUT

# %%
train_df = pd.concat([rna_train, mut_train], axis=1)
test_df = pd.concat([rna_test, mut_test], axis=1)

# %%
# elastic net
run_elastic_net(train_df, y_train, test_df, y_test, "2-Multimodal-OmicOnly/rna_mut_")

# %% [markdown]
# ### Combo 11: CNV + MUT

# %%
train_df = pd.concat([cnv_train, mut_train], axis=1)
test_df = pd.concat([cnv_test, mut_test], axis=1)

# %%
# elastic net
run_elastic_net(train_df, y_train, test_df, y_test, "2-Multimodal-OmicOnly/cnv_mut_")
