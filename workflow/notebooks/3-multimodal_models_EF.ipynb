# %%
import os
import sys
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

dir = "/Users/julianguyen/Documents/multimodal-pmlb"
os.chdir(dir)
sys.path.insert(0, dir)
from workflow.notebooks.utils.late_helpers import *

np.random.seed(101)

# %%
# load in files
atc = pd.read_csv("data/procdata/model_inputs/atc.csv", index_col=0)
rna = pd.read_csv("data/procdata/model_inputs/rna.csv", index_col=0)
cnv = pd.read_csv("data/procdata/model_inputs/cnv.csv", index_col=0)
mut = pd.read_csv("data/procdata/model_inputs/mut.csv", index_col=0)
pheno = pd.read_csv("data/procdata/model_inputs/meta.csv", index_col=0)

# get targest
dt = pheno["doubling_rate"]

# %% [markdown]
# ## Multimodal Models WITHOUT Cancer Type
#
# Multimodal modelling done using early fusion. Evaluating all combinations of available omics data.

# %% [markdown]
# ### Combo 1: All Modalities

# %%
X = pd.concat([atc, rna, cnv, mut], axis=1)

# %%
run_lasso(X, dt, "2-Multimodal-OmicOnly/all_modalities_")
run_elastic_net(X, dt, "2-Multimodal-OmicOnly/all_modalities_")
run_random_forest(X, dt, "2-Multimodal-OmicOnly/all_modalities_")

# %% [markdown]
# ### Combo 2: ATAC + RNA + CNV

# %%
X = pd.concat([atc, rna, cnv], axis=1)

# %%
#run_lasso(X, dt, "2-Multimodal-OmicOnly/atac_rna_cnv_")
run_elastic_net(X, dt, "2-Multimodal-OmicOnly/atac_rna_cnv_")
run_random_forest(X, dt, "2-Multimodal-OmicOnly/atac_rna_cnv_")

# %% [markdown]
# ### Combo 3: ATAC + RNA + MUT

# %%
X = pd.concat([atc, rna, mut], axis=1)

# %%
#run_lasso(X, dt, "2-Multimodal-OmicOnly/atac_rna_mut_")
run_elastic_net(X, dt, "2-Multimodal-OmicOnly/atac_rna_mut_")
run_random_forest(X, dt, "2-Multimodal-OmicOnly/atac_rna_mut_")

# %% [markdown]
# ### Combo 4: ATAC + CNV + MUT

# %%
X = pd.concat([atc, cnv, mut], axis=1)

# %%
#run_lasso(X, dt, "2-Multimodal-OmicOnly/atac_cnv_mut_")
run_elastic_net(X, dt, "2-Multimodal-OmicOnly/atac_cnv_mut_")
run_random_forest(X, dt, "2-Multimodal-OmicOnly/atac_cnv_mut_")

# %% [markdown]
# ### Combo 5: ATAC + RNA

# %%
X = pd.concat([atc, rna], axis=1)

# %%
run_lasso(X, dt, "2-Multimodal-OmicOnly/atac_rna_")
run_elastic_net(X, dt, "2-Multimodal-OmicOnly/atac_rna_")
run_random_forest(X, dt, "2-Multimodal-OmicOnly/atac_rna_")

# %% [markdown]
# ### Combo 6: ATAC + CNV

# %%
X = pd.concat([atc, cnv], axis=1)

# %%
#run_lasso(X, dt, "2-Multimodal-OmicOnly/atac_cnv_")
run_elastic_net(X, dt, "2-Multimodal-OmicOnly/atac_cnv_")
run_random_forest(X, dt, "2-Multimodal-OmicOnly/atac_cnv_")

# %% [markdown]
# ### Combo 7: ATAC + MUT

# %%
X = pd.concat([atc, mut], axis=1)

# %%
#run_lasso(X, dt, "2-Multimodal-OmicOnly/atac_mut_")
run_elastic_net(X, dt, "2-Multimodal-OmicOnly/atac_mut_")
run_random_forest(X, dt, "2-Multimodal-OmicOnly/atac_mut_")

# %% [markdown]
# ### Combo 8: RNA + CNV + MUT

# %%
X = pd.concat([rna, cnv, mut], axis=1)

# %%
#run_lasso(X, dt, "2-Multimodal-OmicOnly/rna_cnv_mut_")
run_elastic_net(X, dt, "2-Multimodal-OmicOnly/rna_cnv_mut_")
run_random_forest(X, dt, "2-Multimodal-OmicOnly/rna_cnv_mut_")

# %% [markdown]
# ### Combo 9: RNA + CNV

# %%
X = pd.concat([rna, cnv], axis=1)

# %%
#run_lasso(X, dt, "2-Multimodal-OmicOnly/rna_cnv_")
run_elastic_net(X, dt, "2-Multimodal-OmicOnly/rna_cnv_")
run_random_forest(X, dt, "2-Multimodal-OmicOnly/rna_cnv_")

# %% [markdown]
# ### Combo 10: RNA + MUT

# %%
X = pd.concat([rna, mut], axis=1)

# %%
#run_lasso(X, dt, "2-Multimodal-OmicOnly/rna_mut_")
run_elastic_net(X, dt, "2-Multimodal-OmicOnly/rna_mut_")
run_random_forest(X, dt, "2-Multimodal-OmicOnly/rna_mut_")

# %% [markdown]
# ### Combo 11: CNV + MUT

# %%
X = pd.concat([cnv, mut], axis=1)

# %%
#run_lasso(X, dt, "2-Multimodal-OmicOnly/cnv_mut_")
run_elastic_net(X, dt, "2-Multimodal-OmicOnly/cnv_mut_")
run_random_forest(X, dt, "2-Multimodal-OmicOnly/cnv_mut_")
